# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/playground-series-s3e14/sample_submission.csv
# /kaggle/input/playground-series-s3e14/train.csv
# /kaggle/input/playground-series-s3e14/test.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
train_data = pd.read_csv("/kaggle/input/playground-series-s3e14/train.csv")
train_data.head()
# Out:
#    id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0   0       25.0      0.50     0.25     0.75   0.50              69.7
# 1   1       25.0      0.50     0.25     0.50   0.50              69.7
# 2   2       12.5      0.25     0.25     0.63   0.63              86.0
# 3   3       12.5      0.25     0.25     0.63   0.50              77.4
# 4   4       25.0      0.50     0.25     0.63   0.63              77.4
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              42.1                  58.2              50.2              24.3
# 1              42.1                  58.2              50.2              24.3
# 2              52.0                  71.9              62.0              30.0
# 3              46.8                  64.7              55.8              27.0
# 4              46.8                  64.7              55.8              27.0
#
# ...

# %%
train_data.columns
# Out:
# Index(['id', 'clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia',
#        'MaxOfUpperTRange', 'MinOfUpperTRange', 'AverageOfUpperTRange',
#        'MaxOfLowerTRange', 'MinOfLowerTRange', 'AverageOfLowerTRange',
#        'RainingDays', 'AverageRainingDays', 'fruitset', 'fruitmass', 'seeds',
#        'yield'],
#       dtype='object')

# %%
test_data = pd.read_csv("/kaggle/input/playground-series-s3e14/test.csv")
test_data.head()
# Out:
#       id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0  15289       25.0      0.25     0.25     0.25   0.25              86.0
# 1  15290       12.5      0.25     0.25     0.75   0.63              94.6
# 2  15291       12.5      0.25     0.25     0.63   0.63              86.0
# 3  15292       25.0      0.50     0.38     0.38   0.63              86.0
# 4  15293       37.5      0.75     0.25     0.25   0.25              94.6
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              52.0                  71.9              62.0              30.0
# 1              57.2                  79.0              68.2              33.0
# 2              52.0                  71.9              62.0              30.0
# 3              52.0                  71.9              62.0              30.0
# 4              57.2                  79.0              68.2              33.0
#
# ...

# %%
test_data.columns
# Out:
# Index(['id', 'clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia',
#        'MaxOfUpperTRange', 'MinOfUpperTRange', 'AverageOfUpperTRange',
#        'MaxOfLowerTRange', 'MinOfLowerTRange', 'AverageOfLowerTRange',
#        'RainingDays', 'AverageRainingDays', 'fruitset', 'fruitmass', 'seeds'],
#       dtype='object')

# %%
train_data.isnull().sum()
# Out:
# id                      0
# clonesize               0
# honeybee                0
# bumbles                 0
# andrena                 0
# osmia                   0
# MaxOfUpperTRange        0
# MinOfUpperTRange        0
# AverageOfUpperTRange    0
# MaxOfLowerTRange        0
# MinOfLowerTRange        0
# AverageOfLowerTRange    0
# RainingDays             0
# AverageRainingDays      0
# fruitset                0
# fruitmass               0
# seeds                   0
# yield                   0
# dtype: int64

# %%
train_data.describe()
# Out:
#                  id     clonesize      honeybee       bumbles       andrena  \
# count  15289.000000  15289.000000  15289.000000  15289.000000  15289.000000
# mean    7644.000000     19.704690      0.389314      0.286768      0.492675
# std     4413.698468      6.595211      0.361643      0.059917      0.148115
# min        0.000000     10.000000      0.000000      0.000000      0.000000
# 25%     3822.000000     12.500000      0.250000      0.250000      0.380000
# 50%     7644.000000     25.000000      0.500000      0.250000      0.500000
# 75%    11466.000000     25.000000      0.500000      0.380000      0.630000
# max    15288.000000     40.000000     18.430000      0.585000      0.750000
#
#               osmia  MaxOfUpperTRange  MinOfUpperTRange  AverageOfUpperTRange  \
# count  15289.000000      15289.000000      15289.000000          15289.000000
# mean       0.592355         82.169887         49.673281             68.656256
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15289 entries, 0 to 15288
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15289 non-null  int64
#  1   clonesize             15289 non-null  float64
#  2   honeybee              15289 non-null  float64
#  3   bumbles               15289 non-null  float64
#  4   andrena               15289 non-null  float64
#  5   osmia                 15289 non-null  float64
#  6   MaxOfUpperTRange      15289 non-null  float64
#  7   MinOfUpperTRange      15289 non-null  float64
#  8   AverageOfUpperTRange  15289 non-null  float64
#  9   MaxOfLowerTRange      15289 non-null  float64
#  10  MinOfLowerTRange      15289 non-null  float64
#  11  AverageOfLowerTRange  15289 non-null  float64
#  12  RainingDays           15289 non-null  float64
#  13  AverageRainingDays    15289 non-null  float64
# ...

# %%
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, r2_score, mean_squared_error, mean_absolute_error

# %%
train_data.corr()
# Out:
#                             id  clonesize  honeybee   bumbles   andrena  \
# id                    1.000000   0.003041  0.013690  0.003244  0.008948
# clonesize             0.003041   1.000000  0.304130  0.080433  0.065131
# honeybee              0.013690   0.304130  1.000000 -0.017937  0.030671
# bumbles               0.003244   0.080433 -0.017937  1.000000 -0.164962
# andrena               0.008948   0.065131  0.030671 -0.164962  1.000000
# osmia                 0.004693  -0.007607 -0.010394  0.158001  0.309556
# MaxOfUpperTRange      0.009528   0.016159  0.005840 -0.002104 -0.013061
# MinOfUpperTRange      0.009613   0.015838  0.005755 -0.001813 -0.012928
# AverageOfUpperTRange  0.009504   0.016057  0.005892 -0.001769 -0.012993
# MaxOfLowerTRange      0.009756   0.016343  0.005942 -0.001613 -0.012924
# MinOfLowerTRange      0.009544   0.016026  0.005809 -0.001804 -0.013035
# AverageOfLowerTRange  0.009608   0.015987  0.005485 -0.001644 -0.013071
# ...

# %%
sns.scatterplot(y = train_data["yield"], x = train_data ["honeybee"])
# Out:
# <AxesSubplot: xlabel='honeybee', ylabel='yield'>

# %%
sns.regplot(y = train_data.corr()["yield"], x = train_data.corr() ["honeybee"])
# Out:
# <AxesSubplot: xlabel='honeybee', ylabel='yield'>

# %%
#Method of finding outliers

print("Highest allowed", train_data["honeybee"].mean() + 3*train_data["honeybee"].std())
print("Lowest allowed",train_data["honeybee"].mean()- 3*train_data["honeybee"].std())
# Out:
# Highest allowed 1.4742435742990594
# Lowest allowed -0.6956150178205456

# %%
new_data = train_data[(train_data["honeybee"] < 1.47424) & (train_data["honeybee"] > -0.6956)]
new_data
# Out:
#           id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0          0       25.0      0.50     0.25     0.75   0.50              69.7
# 1          1       25.0      0.50     0.25     0.50   0.50              69.7
# 2          2       12.5      0.25     0.25     0.63   0.63              86.0
# 3          3       12.5      0.25     0.25     0.63   0.50              77.4
# 4          4       25.0      0.50     0.25     0.63   0.63              77.4
# ...      ...        ...       ...      ...      ...    ...               ...
# 15284  15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285  15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286  15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287  15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288  15288       25.0      0.50     0.25     0.63   0.50              77.4
#
# ...

# %%
sns.distplot(new_data["honeybee"])
# Out:
# /tmp/ipykernel_20/4003262365.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_data["honeybee"])
# <AxesSubplot: xlabel='honeybee', ylabel='Density'>

# %%
#deleting id and yield from data

X=new_data.drop(columns=["id","yield"])
X.shape
# Out:
# (15281, 16)

# %%
X
# Out:
#        clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0           25.0      0.50     0.25     0.75   0.50              69.7
# 1           25.0      0.50     0.25     0.50   0.50              69.7
# 2           12.5      0.25     0.25     0.63   0.63              86.0
# 3           12.5      0.25     0.25     0.63   0.50              77.4
# 4           25.0      0.50     0.25     0.63   0.63              77.4
# ...          ...       ...      ...      ...    ...               ...
# 15284       12.5      0.25     0.25     0.38   0.50              77.4
# 15285       12.5      0.25     0.25     0.25   0.50              86.0
# 15286       25.0      0.50     0.25     0.38   0.75              77.4
# 15287       25.0      0.50     0.25     0.63   0.63              69.7
# 15288       25.0      0.50     0.25     0.63   0.50              77.4
#
#        MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# ...

# %%
Y=new_data["yield"]
Y.shape
# Out:
# (15281,)

# %%
Y
# Out:
# 0        4476.81146
# 1        5548.12201
# 2        6869.77760
# 3        6880.77590
# 4        7479.93417
#             ...
# 15284    7667.83619
# 15285    3680.56025
# 15286    4696.44394
# 15287    6772.93347
# 15288    5867.99722
# Name: yield, Length: 15281, dtype: float64

# %%
#mean of 0 and sd of 1

normalized_data=(X-X.mean())/X.std()
normalized_data
# Out:
#        clonesize  honeybee   bumbles   andrena     osmia  MaxOfUpperTRange  \
# 0       0.802716  0.913560 -0.617183  1.738761 -0.665822         -1.363005
# 1       0.802716  0.913560 -0.617183  0.048483 -0.665822         -1.363005
# 2      -1.092104 -1.024974 -0.617183  0.927428  0.269133          0.418691
# 3      -1.092104 -1.024974 -0.617183  0.927428 -0.665822         -0.521345
# 4       0.802716  0.913560 -0.617183  0.927428  0.269133         -0.521345
# ...          ...       ...       ...       ...       ...               ...
# 15284  -1.092104 -1.024974 -0.617183 -0.762850 -0.665822         -0.521345
# 15285  -1.092104 -1.024974 -0.617183 -1.641794 -0.665822          0.418691
# 15286   0.802716  0.913560 -0.617183 -0.762850  1.132169         -0.521345
# 15287   0.802716  0.913560 -0.617183  0.927428  0.269133         -1.363005
# 15288   0.802716  0.913560 -0.617183  0.927428 -0.665822         -0.521345
#
#        MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# ...

# %%
model = RandomForestRegressor(n_estimators = 250, random_state = 0)

# Fitting the Random Forest Regression model to the data
model.fit(X, Y)
# Out:
# RandomForestRegressor(n_estimators=250, random_state=0)

# %%
X_test=test_data.drop(columns="id")

# %%
#normalized test data

X_testn=(X_test-X_test.mean())/X_test.std()
X_testn
# Out:
#        clonesize  honeybee   bumbles   andrena     osmia  MaxOfUpperTRange  \
# 0       0.789464 -0.363070 -0.606473 -1.628765 -2.453385          0.414378
# 1      -1.106813 -0.363070 -0.606473  1.745819  0.262894          1.353915
# 2      -1.106813 -0.363070 -0.606473  0.935919  0.262894          0.414378
# 3       0.789464  0.277919  1.565024 -0.751373  0.262894          0.414378
# 4       2.685741  0.918908 -0.606473 -1.628765 -2.453385          1.353915
# ...          ...       ...       ...       ...       ...               ...
# 10189   0.789464 -0.363070 -0.606473 -1.628765 -2.453385          0.414378
# 10190   0.789464  0.277919 -0.606473  0.058527  1.120667         -0.525159
# 10191   0.789464  0.277919  1.565024  0.058527 -0.666359         -0.525159
# 10192  -1.106813 -0.363070 -0.606473 -0.751373 -0.666359          1.353915
# 10193  -1.106813 -0.363070 -0.606473  0.058527 -0.666359         -0.525159
#
#        MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# ...

# %%
predict=model.predict(X_test)

# %%
predict = pd.DataFrame(predict)
predict = predict.head(15281)

# %%
r2 = r2_score(Y[:len(predict)], predict)
print("R2 Score:", r2)
# Out:
# R2 Score: -0.8427633795641374
